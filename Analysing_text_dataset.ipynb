# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\srish\OneDrive\Documents\Internships\Millipixels\Week 3-4\ai_vs_human_content.csv")

# %%
df.head()
# Out:
#    id                                          prompt  \
# 0   1  Write a string manipulation solution in python
# 1   2                  Explain health in simple terms
# 2   3        Summarize recent developments in finance
# 3   4        Summarize recent developments in finance
# 4   5      Provide a graph traversal algorithm in cpp
#
#                                              content  type     source  label  \
# 0  def string_manipulation():\n    # TODO: implem...  code       blog  human
# 1  Experts recommend focusing on health to improv...  text  generated     ai
# 2  The development of finance technologies has ac...  text  generated     ai
# 3  Recent studies show that finance can have sign...  text  generated     ai
# 4  vector<int> arr; // graph traversal example\nf...  code  generated     ai
#
#                  topic  word_count  char_count ai_model language  \
# 0  string manipulation           9          84      NaN   python
# ...

# %%
print(df.head())
# Out:
#    id                                          prompt  \
# 0   1  Write a string manipulation solution in python
# 1   2                  Explain health in simple terms
# 2   3        Summarize recent developments in finance
# 3   4        Summarize recent developments in finance
# 4   5      Provide a graph traversal algorithm in cpp
#
#                                              content  type     source  label  \
# 0  def string_manipulation():\n    # TODO: implem...  code       blog  human
# 1  Experts recommend focusing on health to improv...  text  generated     ai
# 2  The development of finance technologies has ac...  text  generated     ai
# 3  Recent studies show that finance can have sign...  text  generated     ai
# 4  vector<int> arr; // graph traversal example\nf...  code  generated     ai
#
#                  topic  word_count  char_count ai_model language  \
# 0  string manipulation           9          84      NaN   python
# ...

# %%
print(df.shape)
# Out:
# (20000, 13)

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 20000 non-null  int64
#  1   prompt             20000 non-null  str
#  2   content            20000 non-null  str
#  3   type               20000 non-null  str
#  4   source             20000 non-null  str
#  5   label              20000 non-null  str
#  6   topic              20000 non-null  str
#  7   word_count         20000 non-null  int64
#  8   char_count         20000 non-null  int64
#  9   ai_model           10004 non-null  str
#  10  language           20000 non-null  str
#  11  complexity_score   20000 non-null  int64
#  12  is_multiline_code  20000 non-null  bool
# dtypes: bool(1), int64(4), str(8)
# memory usage: 1.9 MB
# None

# %%
print(df.describe())
# Out:
#                  id    word_count    char_count  complexity_score
# count  20000.000000  20000.000000  20000.000000       20000.00000
# mean   10000.500000     28.317100    206.635150           5.50605
# std     5773.647028     17.297994    122.430413           2.88010
# min        1.000000      9.000000     52.000000           1.00000
# 25%     5000.750000     13.000000     96.000000           3.00000
# 50%    10000.500000     25.000000    176.500000           6.00000
# 75%    15000.250000     43.000000    314.000000           8.00000
# max    20000.000000     67.000000    473.000000          10.00000

# %%
print(df.columns.tolist())
# Out:
# ['id', 'prompt', 'content', 'type', 'source', 'label', 'topic', 'word_count', 'char_count', 'ai_model', 'language', 'complexity_score', 'is_multiline_code']

# %%
print(df['label'].value_counts())
# Out:
# label
# ai       10004
# human     9996
# Name: count, dtype: int64

# %%
print(df['type'].value_counts())
# Out:
# type
# text    10004
# code     9996
# Name: count, dtype: int64

# %%
print(df['topic'].value_counts())
# Out:
# topic
# sorting algorithm      2056
# graph traversal        2007
# dynamic programming    1997
# binary search          1976
# string manipulation    1960
# sports                 1725
# finance                1700
# education              1685
# politics               1641
# health                 1639
# tech                   1614
# Name: count, dtype: int64
